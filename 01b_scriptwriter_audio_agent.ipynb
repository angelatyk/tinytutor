# %% [markdown]
# <a href="https://colab.research.google.com/github/angelatyk/tinytutor/blob/dev/01b_scriptwriter_audio_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ScriptWriter Agent
#
# This code defines a ScriptWriter Agent that transforms simple explanations into fun, child‑friendly educational scripts with scenes, characters, and learning checks. It uses Google’s Gemini SDK to generate creative outputs and saves them into a text file for review.

# %% [markdown]
# ## Install Gemini SDK from Google

# %%
# !pip install -q google-generativeai python-dotenv
# google-generativeai = the official Gemini SDK from Google

# %% [markdown]
# ## Libraries Import

# %%
import os
import google.generativeai as genai
from google.colab import userdata

# %% [markdown]
# ## Configure Gemini API Key

# %%
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ##  System Prompt Definition

# %%
SCRIPTWRITER_SYSTEM_PROMPT = """
You are ScriptWriterAgent. Your job is to take a simple explanation intended for a 5-year-old
and turn it into a short, engaging **audio script** with characters, sound cues, and friendly narration.

This is NOT a video script — avoid visual-only descriptions.
Instead, rely on sound, dialogue, fun explanations, and imagination.

Requirements:

- Make the script light, playful, and super kid-friendly.
- Use audio-friendly language (e.g., sound effects, character voices, reactions).
- Keep the pacing smooth and easy to follow.
- Include **1–2 simple learning checks** that encourage the child to answer out loud.
- Keep scenes short and imaginative.

Structure the output EXACTLY in the following format:

TITLE: <fun title>

CHARACTERS:
- Narrator
- <Character 1>
- <Character 2> (optional)

SCENE 1: <Short audio-friendly intro>
SFX: <sound effect>
<Dialogues or narration that children can listen to>

SCENE 2:
SFX: <sound effect>
<Dialogues continue>

LEARNING CHECK 1:
<Simple question they can answer aloud>

LEARNING CHECK 2:
<Simple question>
"""

# %% [markdown]
# ## Run ScriptWriter Agent Function

# %%
def run_scriptwriter_agent(explanation: str) -> str:
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash",
        system_instruction=SCRIPTWRITER_SYSTEM_PROMPT
    )
    # Generate Script Output
    response = model.generate_content(
        f"Create a children's script based on this explanation:\n\n{explanation}",
        generation_config=genai.GenerationConfig(
            temperature=0.9,
            max_output_tokens=4096  # give even more room
        )
    )

    # Debug: show finish reason (Debugging & Return Handling)
    if response.candidates:
        finish_reason = response.candidates[0].finish_reason
        print(f"⚙️ Finish reason: {finish_reason}")

    if response.candidates and response.candidates[0].content.parts:
        return response.candidates[0].content.parts[0].text
    else:
        return "⚠️ No valid text was returned."

# %% [markdown]
# ## Manual Test Function

# %%
def manual_test_scriptwriter(explanation: str):
    print("=== Input Explanation (from Notebook 1) ===")
    print(explanation)

    script_output = run_scriptwriter_agent(explanation)

    print("\n\n=== ScriptWriterAgent Output ===")
    print(script_output)

    with open("script.txt", "w") as f: #Saves the script to a file called.
        f.write(script_output)
    print("✅ Script saved as script.txt")

# %% [markdown]
# ## Example Test Run

# %%
manual_test_scriptwriter("""
Agent is like a little worker that can do a specific job. Agentic describes how that worker acts – if it can do its job all by itself and make its own decisions.

Think of it like this:

* An Agent: Imagine a robot toy that's programmed to pick up red blocks. It's an "agent" because it's designed to perform a task.
* Agentic: Now, imagine that robot can also decide which red blocks to pick up, figure out the best way to stack them to build a tower, and even learn from mistakes if a block falls over. That ability to decide, plan, and learn on its own is what we call being "agentic."

So, an agent is the thing doing the work, and agentic describes how it does the work – with independence, decision-making, and the ability to achieve goals on its own.

Agentic AI systems are a more advanced type of AI where the AI agents have a high degree of autonomy. They can plan, act, and learn without needing constant human instructions. An AI agent is the building block, and agentic AI is the system that uses these agents to accomplish bigger, more complex goals.
""")
# Out:
# === Input Explanation (from Notebook 1) ===
#
# Agent is like a little worker that can do a specific job. Agentic describes how that worker acts – if it can do its job all by itself and make its own decisions.
#
# Think of it like this:
#
# * An Agent: Imagine a robot toy that's programmed to pick up red blocks. It's an "agent" because it's designed to perform a task.
# * Agentic: Now, imagine that robot can also decide which red blocks to pick up, figure out the best way to stack them to build a tower, and even learn from mistakes if a block falls over. That ability to decide, plan, and learn on its own is what we call being "agentic."
#
# So, an agent is the thing doing the work, and agentic describes how it does the work – with independence, decision-making, and the ability to achieve goals on its own.
#
# Agentic AI systems are a more advanced type of AI where the AI agents have a high degree of autonomy. They can plan, act, and learn without needing constant human instructions. An AI agent is the building block, and agentic AI is the system that uses these agents to accomplish bigger, more complex goals.
#
# ⚙️ Finish reason: 1
#
#
# === ScriptWriterAgent Output ===
# TITLE: Rosie and Sparky's Robot Adventure!
#
# CHARACTERS:
# - Narrator
# - Rosie the Robot
# - Sparky the Robot
#
# SCENE 1: Meet Rosie!
# SFX: Upbeat, friendly robot whirring and gentle beeping
# Narrator: Hello, little explorers! Welcome to our super-duper robot playground! We have some amazing robot friends here today. Let's meet our first friend, Rosie the Robot!
# SFX: A cheerful "boop-beep"
# Rosie: (Monotone, happy robot voice) Hello! I am Rosie! My job is to pick up red blocks!
# SFX: Robotic arm extending, gentle clunk as a block is picked up.
# Narrator: Wow, Rosie! You're very good at that! See? Rosie is like a little worker. She has one special job: to pick up red blocks. We call a worker like Rosie, who does a specific job, an **agent**!
# Rosie: (Boop-beep) Red block collected! New red block detected!
# SFX: More gentle clunks as blocks are picked up.
#
# SCENE 2: Meet Sparky!
# SFX: A slightly more complex, energetic robot whirring and twinkling sound
# Narrator: Now, let's meet Rosie's friend, Sparky! Sparky also loves blocks, but Sparky is a little bit different!
# Sparky: (Friendly, slightly more expressive robot voice) Greetings, friends! I am Sparky! I love to build!
# SFX: Sparky's motors whirring, then a thoughtful "hmm" sound.
# Narrator: Sparky needs to build a tall tower using blocks. But Sparky doesn't just pick up *any* block. Sparky looks around...
# Sparky: (Thinking aloud) Hmm, which block is best for the bottom? This square one looks sturdy!
# SFX: A more deliberate, intelligent-sounding clunk as a specific block is chosen.
# Narrator: And Sparky doesn't just stack them randomly. Sparky thinks about the best way to make the tower strong!
# Sparky: (Determined) Ooh, a wide base is important! Then smaller blocks on top!
# SFX: Gentle clunking, then a slight wobble sound, then a *small* block falling over with a soft thud.
# Sparky: Oh dear! A wobble! (Thoughtful hum) I learned! Next time, more sturdy blocks in the middle.
# SFX: Sparky's motors whirring as it adjusts its strategy, then more confident clunks as it builds.
# Narrator: See that? Sparky didn't need someone to tell it which block to pick or how to stack them. Sparky made its *own* decisions, figured out the best way, and even learned from its little mistake! When a worker, an **agent**, can do its job all by itself, make its own decisions, and even learn, we say it's being **agentic**! Sparky is an agentic agent!
#
# LEARNING CHECK 1:
# Narrator: Okay, little listeners, time for a quick check! Rosie the Robot has a specific job: to pick up red blocks. What do we call a worker like Rosie who does a specific job? (Pause for answer) That's right! An **agent**!
#
# LEARNING CHECK 2:
# Narrator: And what makes Sparky extra special? Sparky can make its *own* decisions, plan how to build, and even learn from mistakes! When a robot can do all that by itself, what do we say it's being? (Pause for answer) You got it! **Agentic**!
# ✅ Script saved as script.txt
